# %% [markdown]
# Start master and worker: https://stackoverflow.com/a/74825421

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .master("spark://127.0.0.1:7077") \
    .appName('pyspark-run-with-gcp-bucket2') \
    .config("spark.jars", "/home/kantundpeterpan/projects/zoomcamp/zcde_space/week5/gcs-connector-hadoop3-latest.jar") \
    .getOrCreate()
# Out:
# 25/03/06 23:47:49 WARN Utils: Your hostname, mystuff resolves to a loopback address: 127.0.1.1; using 193.168.147.155 instead (on interface eth0)
# 25/03/06 23:47:49 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 25/03/06 23:47:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/03/06 23:47:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# Configure GCS authentication
spark.conf.set("google.cloud.auth.service.account.enable", "true")
spark._jsc.hadoopConfiguration().set("google.cloud.auth.service.account.json.keyfile", 
                                     "/home/kantundpeterpan/projects/zoomcamp/zcde_space/week1/3_intro_terraform/workspaceaddon-436615-4bcf737409b7.json")
spark._jsc.hadoopConfiguration().set('fs.gs.impl', 'com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem')

# %%
bucket_url = 'gs://workspaceaddon-436615'

# %%
df_green = spark.read.parquet(bucket_url + '/green/*/*')
# Out:
# 25/03/06 23:51:43 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 25/03/06 23:51:58 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 25/03/06 23:52:13 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 25/03/06 23:52:28 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
